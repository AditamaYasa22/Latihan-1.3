# %%
print ("Nama saya Aditama Yasa")
# Out:
# Nama saya Aditama Yasa

# %%
print ("dari prodi Teknik Informatika")
# Out:
# dari prodi Teknik Informatika

# %%
print ("Kelas TI22E")
# Out:
# Kelas TI22E

# %%
print ("Asal Sekolah SMA Negeri 5 Kota Sukabumi")
# Out:
# Asal Sekolah SMA Negeri 5 Kota Sukabumi
