# %%
print ("hari minggu")
# Out:
# hari minggu

# %%
print ("adalah hari")
# Out:
# adalah hari

# %%
print ("yang paling")
# Out:
# yang paling

# %%
print ("saya suka")
# Out:
# saya suka

# %%
print ("karena hari minggu")
# Out:
# karena hari minggu

# %%
print ("adalah hari libur")
# Out:
# adalah hari libur
